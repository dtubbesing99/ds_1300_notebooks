# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.
#
# Upload a pdf of the plot to Canvas.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings

# %%
pwd
# Out:
# '/users/dtubbesing/ds_1300_notebooks/code'

# %%
serves = pd.read_csv('/users/dtubbesing/ds_1300_notebooks/work/serves.csv')
serves
# Out:
#     Nationality                   name  Serve Rating  % 1st Serve  \
# 0           USA             John Isner         312.1         0.69
# 1           CRO           Ivo Karlovic         309.8         0.66
# 2           USA          Reilly Opelka         303.4         0.64
# 3           CAN           Milos Raonic         302.8         0.63
# 4           USA           Andy Roddick         299.9         0.65
# ..          ...                    ...           ...          ...
# 96          ESP  Roberto Bautista Agut         271.2         0.66
# 97          ARG           Javier Frana         271.2         0.62
# 98          BRA        Gustavo Kuerten         271.0         0.55
# 99          ARG         Leonardo Mayer         271.0         0.61
# 100         GER         Alex Radulescu         271.0         0.56
#
#      % 1st Serve Points Won  % 2nd Serve Points Won  % Service Games Won  \
# 0                      0.79                    0.56                 0.92
# ...

# %%
serv=serves.groupby(by='Nationality').mean()
ser=serv[['% 1st Serve','% 1st Serve Points Won','% 2nd Serve Points Won','% Service Games Won']]
ser
# Out:
#              % 1st Serve  % 1st Serve Points Won  % 2nd Serve Points Won  \
# Nationality
# ARG             0.623333                0.733333                0.520000
# AUS             0.617000                0.763000                0.515000
# AUT             0.610000                0.740000                0.530000
# BEL             0.630000                0.760000                0.510000
# BRA             0.600000                0.735000                0.520000
# BUL             0.620000                0.750000                0.510000
# CAN             0.610000                0.772500                0.515000
# CHI             0.620000                0.735000                0.520000
# COR             0.620000                0.720000                0.530000
# CRO             0.594000                0.794000                0.518000
# CZE             0.610000                0.750000                0.515000
# ESP             0.643333                0.720000                0.538333
# ...

# %%
s=ser.plot.bar(title='Serve Percentages by Nationality', figsize=(20,5))
s.set_ylabel('Serve Percentages')
# Out:
# Text(0, 0.5, 'Serve Percentages')

# %%
#5
#My plot shows various average serve percentages compared to players' nationalities

# %%
#6
#I made it a bar graph so it is easy to see the different nationalities in comparison to serve percentages
